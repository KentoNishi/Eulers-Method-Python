# %%
# %run "C:\\Users\\kento\\Documents\\GitHub\\Eulers-Method-Python\\euler.py"
import math

# %%
class Derivative:
    def evaluate(self, x, y):
        return (1 + math.exp(x))/math.pow(x,2)

# %%
calc = EulerCalculator()
points = calc.evaluate(Derivative(), 3, 6, 3.1, stepSize=0.05)
calc.graph(points)
# Out:
# x        y
# ----  -------
# 3     6
# 3.05  6.11887
# 3.1   6.23956
