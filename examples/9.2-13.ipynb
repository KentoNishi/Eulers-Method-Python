# %%
# %run "C:\\Users\\kento\\Documents\\GitHub\\Eulers-Method-Python\\euler.py"

# %%
class Derivative:
    def evaluate(self, x, y):
        return y** (1. / 3)

# %%
calc = EulerCalculator()
points = calc.evaluate(Derivative(), 0, 1, 4, stepSize=0.5)
calc.graph(points)
# Out:
# x        y
# ---  -------
# 0    1
# 0.5  1.5
# 1    2.07236
# 1.5  2.70982
# 2    3.40691
# 2.5  4.15926
# 3    4.96336
# 3.5  5.81625
# 4    6.71544
